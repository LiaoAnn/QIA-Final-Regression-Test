# %% [markdown]
# ### TPE-sample1

# %%
# %reload_ext autoreload
# %autoreload 2


# === 載入必要模組 ===
import pandas as pd

# 匯入策略與繪圖函數
from lib.backtest.strategy_one import backtest_strategy as backtest_strategy_one
from lib.backtest.strategy_two import backtest_strategy_two
from lib.backtest.strategy_three import backtest_strategy_three
from lib.backtest.strategy_four import backtest_strategy_four
from lib.plotting import plot_strategy_results

# === 讀取資料 ===
data_path = "../data/TPE-sample1.csv"
df = pd.read_csv(data_path, encoding="utf-8")
df.index = pd.to_datetime(df["Date"]) if "Date" in df.columns else df.index

# === 執行三個策略並直接顯示圖表 ===

# Strategy 1
df1 = backtest_strategy_one(df.copy())
plot_strategy_results(df1, "模組一", ["MA5", "BB_Upper", "BB_Lower"])

# Strategy 2
df2 = backtest_strategy_two(df.copy())
plot_strategy_results(df2, "模組二", ["MA5", "MA20"])

# Strategy 3
df3 = backtest_strategy_three(df.copy())
plot_strategy_results(df3, "模組三", ["MA3", "MA5", "MA10"])

df4 = backtest_strategy_four(df.copy())
plot_strategy_results(df4, "模組四", ["BB_Upper", "BB_Lower", "MA10"])

# %% [markdown]
# ### TPE-sample2

# %%
# %reload_ext autoreload
# %autoreload 2


# === 載入必要模組 ===
import pandas as pd

# 匯入策略與繪圖函數
from lib.backtest.strategy_one import backtest_strategy as backtest_strategy_one
from lib.backtest.strategy_two import backtest_strategy_two
from lib.backtest.strategy_three import backtest_strategy_three
from lib.backtest.strategy_four import backtest_strategy_four
from lib.plotting import plot_strategy_results

# === 讀取資料 ===
data_path = "../data/TPE-sample2.csv"
df = pd.read_csv(data_path, encoding="utf-8")
df.index = pd.to_datetime(df["Date"]) if "Date" in df.columns else df.index

# === 執行三個策略並直接顯示圖表 ===

# Strategy 1
df1 = backtest_strategy_one(df.copy(), ma_period=7, bb_period=15, bb_std=2.5)
plot_strategy_results(df1, "模組一", ["BB_Upper", "BB_Lower"])

# Strategy 2
df2 = backtest_strategy_two(df.copy(), short_ma_period=7, long_ma_period=12)
plot_strategy_results(df2, "模組二", ["MA7", "MA12"])

# Strategy 3
df3 = backtest_strategy_three(df.copy(), ma_short=2, ma_medium=8, ma_long=14)
plot_strategy_results(df3, "模組三", ["MA2", "MA8", "MA14"])

df4 = backtest_strategy_four(df.copy(), bb_period=8, bb_std=1.59, ma_long_period=12)
plot_strategy_results(df4, "模組四", ["BB_MA8", "BB_Upper", "BB_Lower", "MA12"])

# %% [markdown]
# ### TPE-sample3

# %%
# %reload_ext autoreload
# %autoreload 2


# === 載入必要模組 ===
import pandas as pd

# 匯入策略與繪圖函數
from lib.backtest.strategy_one import backtest_strategy as backtest_strategy_one
from lib.backtest.strategy_two import backtest_strategy_two
from lib.backtest.strategy_three import backtest_strategy_three
from lib.backtest.strategy_four import backtest_strategy_four
from lib.plotting import plot_strategy_results

# === 讀取資料 ===
data_path = "../data/TPE-sample3.csv"
df = pd.read_csv(data_path, encoding="utf-8")
df.index = pd.to_datetime(df["Date"]) if "Date" in df.columns else df.index

# === 執行三個策略並直接顯示圖表 ===

# Strategy 1
df1 = backtest_strategy_one(df.copy(), ma_period=7, bb_period=15, bb_std=2.5)
plot_strategy_results(df1, "模組一", ["BB_Upper", "BB_Lower"])

# Strategy 2
df2 = backtest_strategy_two(df.copy(), short_ma_period=7, long_ma_period=12)
plot_strategy_results(df2, "模組二", ["MA7", "MA12"])

# Strategy 3
df3 = backtest_strategy_three(df.copy(), ma_short=2, ma_medium=8, ma_long=14)
plot_strategy_results(df3, "模組三", ["MA2", "MA8", "MA14"])

df4 = backtest_strategy_four(df.copy(), bb_period=8, bb_std=1.59, ma_long_period=12)
plot_strategy_results(df4, "模組四", ["BB_MA8", "BB_Upper", "BB_Lower", "MA12"])
